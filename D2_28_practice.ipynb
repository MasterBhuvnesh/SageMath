# %% [markdown]
# # Name : Bhuvnesh Verma
# # Roll No : D2_28
# # Practice Session I

# %% [markdown]
# #### Question ) Trace the following curves with different thickness colours labels and arrange in 5 x 1 grid .

# %%
var('x y')
f(x,y)=((x^2)/4)+((y^2)/9)-1
p1=implicit_plot(f,(x,-5,5),(y,-5,5),color="pink")
p1
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
a=1
f(x,y)=(y^3)*(2*a-y)-((a^2)*(x^2))
p1=implicit_plot(f,(x,-5,5),(y,-5,5),color="orange")
p1
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x_astroid(t) = cos(t)^3
y_astroid(t) = sin(t)^3
astroid_plot = parametric_plot((x_astroid(t), y_astroid(t)), (t, 0, 2*pi), color='blue', gridlines=True, legend_label='Astroid', figsize=(6, 6))
astroid_plot.axes_labels(['X-axis label', 'Y-axis label'])
show(astroid_plot)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
a=1
x_astroid(t) = a*(t-sin(t))
y_astroid(t) = a*(1-cos(t))
astroid_plot = parametric_plot((x_astroid(t), y_astroid(t)), (t, 0, 2*pi), color='red', gridlines=True, legend_label='Astroid', figsize=(6, 6))
astroid_plot.axes_labels(['X-axis label', 'Y-axis label'])
show(astroid_plot)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(x) = cos(3*x)
plot(f1, (x, 0, 2*pi), color='blue', gridlines=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x,y)=(((x^2)*y)+sin(3*x)^3)/(x^(1/2)+(y/2))
show(f)
# Out:
# (x, y) |--> 2*(x^2*y + sin(3*x)^3)/(y + 2*sqrt(x))

# %%
print("For fxx")
fxx=f.diff(x,2)
show(fxx(x,y))
print("For fxy")
fxy=f.diff(y,2)
show(fxy(x,y))
# Out:
# For fxx
# 2*(54*cos(3*x)^2*sin(3*x) - 27*sin(3*x)^3 + 2*y)/(y + 2*sqrt(x)) - 4*(9*cos(3*x)*sin(3*x)^2 + 2*x*y)/(sqrt(x)*(y + 2*sqrt(x))^2) + (x^2*y + sin(3*x)^3)/(x^(3/2)*(y + 2*sqrt(x))^2) + 4*(x^2*y + sin(3*x)^3)/(x*(y + 2*sqrt(x))^3)
# For fxy
# -4*x^2/(y + 2*sqrt(x))^2 + 4*(x^2*y + sin(3*x)^3)/(y + 2*sqrt(x))^3

# %%
A=random_matrix(ZZ,3,3, x=50 , y=60)
show('A determinent is ',A.det())
show('A adjoint is ',A.adjoint())
show('A inverse is ',A.inverse())
A^5
# Out:
# 'A determinent is ' 816
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/repl/ipython_kernel/__main__.py:3: DeprecationWarning: adjoint is deprecated. Please use adjugate instead.
# See http://trac.sagemath.org/10501 for details.
#   IPKernelApp.launch_instance(kernel_class=SageKernel)
# 'A adjoint is ' [-102  204 -102]
# [ 118 -676  574]
# [   0  408 -408]
# 'A inverse is ' [    -1/8      1/4     -1/8]
# [  59/408 -169/204  287/408]
# [       0      1/2     -1/2]
# [40164411165 36409390365 40686495091]
# [41619979951 37728864303 42160965153]
# [41119292617 37274985417 41653767239]
