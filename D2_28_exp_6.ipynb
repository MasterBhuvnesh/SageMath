# %% [markdown]
# # Name : Bhuvnesh Verma
# # Roll No. : 28
# # Batch : D2
# # Experiment No 6: Curve Fitting
# # Aim: Curve Fitting with SageMath

# %%
data = [(61 , 75),(68 , 62) , (63 , 80),(67 , 98) , (65 , 87),(60 , 43),(67,84)]
point(data , color = "red" , size = 50 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a , b = var('a,b')
y(x)=a+b*x

f1 = find_fit(data , y)
f1
# Out:
# [a == -115.7105263160439, b == 2.968899521535393]

# %%
m1 = y.subs(f1)
m1
# Out:
# x |--> 2.968899521535393*x - 115.7105263160439

# %%
point(data , size = 50 , color ="green" , legend_label = "scatter plot") + plot(m1 , (x , 40 , 100))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
data1 = [(1 , 4),(2 , 6) , (3 , 8),(4 , 9) , (5 , 7),(6 , 4),(7,3)]
point(data1 , color = "red" , size = 50 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a , b , c= var('a, b ,c')
g(x)=a+b*x+c*x^2

f2 = find_fit(data1 , g)
f2
# Out:
# [a == 0.4285714285701434, b == 4.095238095244861, c == -0.547619047622425]

# %%
m2 = y.subs(f2)
m2
# Out:
# x |--> 4.095238095244861*x + 0.4285714285701434

# %%
point(data1 , size = 30 , color ="green" , legend_label = "scatter plot") + plot(m2 , (x , 0 , 8))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
data2 = [(1 , 7.2),(2 , 6.3) , (3 , 4.5),(4 , 2.4) , (5 , 2.01),(6 , 1.23)]
point(data2 , color = "red" , size = 50 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a , b = var('a, b')
g(x) = a*exp(b*x)

f3 = find_fit(data2 , g)
f3
# Out:
# [a == 10.607497859847737, b == -0.3222444475247915]

# %%
m3 = g.subs(f3)
m3
# Out:
# x |--> 10.607497859847737*e^(-0.3222444475247915*x)

# %%
point(data2 , size = 30 , color ="green" , legend_label = "scatter plot") + plot(m3 , (x , 0 , 8))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
data3 = [(2,16,90) , (5,10,72) ,(6 , 8 , 50) ,(8 , 4 , 32) ,(9 , 2 , 12 ) ,(10 , 1 , 8)]
point(data3 , color = "red" , size = 100 , legend_label = "scatter plot")
# Out:
# Graphics3d Object

# %%
a , b , c= var('a, b ,c')
g(x ,y)=a+b*x+c*y

f4 = find_fit(data3 , g)
f4
# Out:
# [a == 96.26666666687395, b == -8.93333333335495, c == 1.0666666666668367]

# %%
m4 = g.subs(f4)
m4
# Out:
# (x, y) |--> -8.93333333335495*x + 1.0666666666668367*y + 96.26666666687395

# %%
point(data3 , color = "red" , size = 100 , legend_label = "scatter plot")+plot3d(m4 , (x,0 , 20) , (y , 0 , 20) , (g , 0 , 20))
# Out:
# Graphics3d Object

# %% [markdown]
# # Exercise Question

# %% [markdown]
# Solution 1:

# %%
data4 = [(12,6.44) , (16 , 7.5) ,(20 , 6.9) ,(22,10.76) ,(24,10.76 ) ,(26 , 11.76) , (30 , 14.0)]
point(data4 , color = "red" , size = 100 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a , b = var('a, b ')
g(x)=a*x + b

f5 = find_fit(data4 , g)
f5
# Out:
# [a == 0.4342783505142298, b == 0.4254639175245253]

# %%
m5 = g.subs(f5)
m5
# Out:
# x |--> 0.4342783505142298*x + 0.4254639175245253

# %%
point(data4 , size = 30 , color ="green" , legend_label = "scatter plot") + plot(m5 , (x , 0 , 40))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Solution 2:

# %%
data5 = [(1,2.98) , (2 , 4.26) ,(3 , 5.21) ,(4,6.1) ,(5,6.8) ,(6 , 7.5)]
point(data5 , color = "red" , size = 100 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a , b = var('a, b ')
g(x)=a*x^b

f6 = find_fit(data5 , g)
f6
# Out:
# [a == 2.974134552834811, b == 0.515433145594774]

# %%
m6 = g.subs(f6)
m6
# Out:
# x |--> 2.974134552834811*x^0.515433145594774

# %%
point(data5 , size = 30 , color ="green" , legend_label = "scatter plot") + plot(m6 , (x , 0 , 10))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Solution 3:

# %%
data = [(2,144),(3,172.3) ,(4,207.4),(5,248.8),(6,298.5)]
point(data , color = "red" , size = 50 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('a,b')
y(x)=a*b^x
f = find_fit(data , y)
f
# Out:
# [a == 99.84048753520109, b == 1.200287701739438]

# %%
m = y.subs(f)
m
# Out:
# x |--> 99.84048753520109*1.200287701739438^x

# %%
point(data , size = 30 , color ="green" , legend_label = "scatter plot") + plot(m , (x , 0 , 8))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Solution 4:

# %%
data6 = [(50,135) , (100 , 48) ,(150, 26) ,(200,17)]
point(data6 , color = "red" , size = 100 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('p,v,r')
k(x) = p*v^x

f7 = find_fit(data6 , k)
f7
# Out:
# [p == 324.4851319421195, v == 0.9823699318779301]

# %%
m7 = k.subs(f7)
m7
# Out:
# x |--> 324.4851319421195*0.9823699318779301^x

# %%
point(data6 , size = 30 , color ="green" , legend_label = "scatter plot") + plot(m7 , (x , 40 , 250))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Solution 5:

# %%
data = [(0,-4),(1,-1),(2,4),(3,11),(4,20)]
point(data , color = "red" , size = 100 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('a,b,c')
k(x) = a*x^2+b*x+c

f = find_fit(data , k)
f
# Out:
# [a == 1.0, b == 2.0, c == -4.0]

# %%
m = k.subs(f)
m
# Out:
# x |--> 1.0*x^2 + 2.0*x - 4.0

# %%
point(data , size = 30 , color ="green" , legend_label = "scatter plot") + plot(m , (x , 0 , 5))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Solution 6:

# %%
data = [(1,5.43),(2,6.28),(3,8.23),(4,10.32),(5,12.63),(6,14.86),(7,17.27),(8,19.51)]
point(data , color = "red" , size = 100 , legend_label = "scatter plot")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('a,b')
k(x) = a*x+(b/x)

f = find_fit(data , k)
f
# Out:
# [a == 2.3971449823057016, b == 3.027802950899304]

# %%
m = k.subs(f)
m
# Out:
# x |--> 2.3971449823057016*x + 3.027802950899304/x

# %%
point(data , size = 30 , color ="green" , legend_label = "scatter plot") + plot(m , (x , 0 , 8))
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Solution 7:

# %%
data = [(57,8,66),(59,10,71),(49,6,53),(62,11,67),(51,8,55),(50,7,58),(55,10,77),(48,9,57),(52,10,56),(42,6,51),(61,12,76),(57,9,68)]
point(data , color = "red" , size = 100 , legend_label = "scatter plot")
# Out:
# Graphics3d Object

# %%
var('a,b,c')
k(x,y) = a+b*x+c*y

f = find_fit(data , k)
f
# Out:
# [a == 1.7315841230124978, b == 0.9326241134750304, c == 1.269280052447098]

# %%
m = k.subs(f)
m
# Out:
# (x, y) |--> 0.9326241134750304*x + 1.269280052447098*y + 1.7315841230124978

# %%
point(data , color = "red" , size = 100 , legend_label = "scatter plot")+plot3d(m , (x,55,65) , (y,6,12) , (z,50,80))
# Out:
# Graphics3d Object
